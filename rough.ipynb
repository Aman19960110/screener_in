# %%
import os
from pathlib import Path
from screener_scrapper import ScreenerClient

for line in Path(".env").read_text(encoding="utf-8").splitlines():
    line = line.strip()
    if line and not line.startswith("#") and "=" in line:
        key, value = line.split("=", 1)
        os.environ.setdefault(key.strip(), value.strip())

client = ScreenerClient(
    username=os.environ["SCREENER_USERNAME"],
    password=os.environ["SCREENER_PASSWORD"],
)

# %%
client.get_symbols_by_company_name('Siemens Ener.Ind')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 client.get_symbols_by_company_name('Siemens Ener.Ind')
#
# AttributeError: 'ScreenerClient' object has no attribute 'get_symbols_by_company_name'

# %%
client.insider_buying()
# Out:
#     S.No.              Name  CMP  Rs.    P/E  Mar Cap  Rs.Cr.  Div Yld  %  \
# 0      1.     Orosil Smiths      6.20   1.12            25.62        0.00
# 1      2.      Sameera Agro      5.30   1.89            31.56        0.00
# 2      3.               BLB     16.49   2.61            87.17        0.00
# 3      4.      Kore Digital    125.45   4.11           150.84        0.00
# 4      5.    Umiya Buildcon     91.95   4.30           172.87        0.00
# 5      6.   Lancor Holdings     24.10   4.34           176.47        0.83
# 6      7.  Shri Kanha Stain     24.45   4.37            38.11        0.00
# 7      8.    Suntech Infra.     32.80   4.62            63.51        0.00
# 8      9.      Kabra Jewels    109.95   4.65           115.28        0.00
# 9     10.    Kaytex Fabrics     58.85   4.95            86.51        0.00
# 10    11.  V.L.Infraproject     27.45   5.12            43.13        0.00
# 11    12.   Mayasheel Vent.     40.00   5.50            88.20        0.00
# ...

# %%
client.insider_trades()
# Out:
#                  Company                                               Name  \
# 0   Defrail Technologies               Vivek Aggarwal Promoter And Director
# 1       Sh. Digvijay Cem  Designated Person (3) Samader Singh, Jayesh So...
# 2        Parsvnath Devl.                        Pradeep Kumar Jain Promoter
# 3        Dhanalaxmi Roto                              Keshav Inani Promoter
# 4       Axtel Industries          Meena Pathak Directors Immediate Relative
# 5             Senco Gold  Jai Hanuman Shri Siddhivinayak Trust Trustee- ...
# 6         Salasar Techno  Promoter Group (2) Shikhar Fabtech Private Lim...
# 7         Salasar Techno                   Alok Kumar Promoter And Director
# 8         Credent Global              Dp Global Wealth Management Llp Other
# 9            Nicco Parks  Promoter Group (2) Nicco Engineering Services ...
# 10       Market Creators  Bina Rashmikant Acharya Promoter Immediate Rel...
# ...

# %%
mask = client.get_all_tables('reliance')

# %%
mask
# Out:
# [           Unnamed: 0 Mar 2023 Jun 2023 Sep 2023 Dec 2023 Mar 2024 Jun 2024  \
#  0             Sales +   212834   207559   231886   225086   236533   231784
#  1          Expenses +   174478   169466   190918   184430   194017   193019
#  2    Operating Profit    38356    38093    40968    40656    42516    38765
#  3               OPM %      18%      18%      18%      18%      18%      17%
#  4      Other Income +     2996     3813     3841     3869     4534     3983
#  5            Interest     5819     5837     5731     5789     5761     5918
#  6        Depreciation    11452    11775    12585    12903    13569    13596
#  7   Profit before tax    24081    24294    26493    25833    27720    23234
#  8               Tax %      11%      25%      25%      25%      24%      25%
#  9        Net Profit +    21327    18258    19878    19641    21243    17445
#  10          EPS in Rs    14.26    11.83    12.85    12.76    14.01    11.19
# ...
