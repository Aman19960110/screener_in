# %%
import os
from pathlib import Path
from screener_scrapper import ScreenerClient

for line in Path(".env").read_text(encoding="utf-8").splitlines():
    line = line.strip()
    if line and not line.startswith("#") and "=" in line:
        key, value = line.split("=", 1)
        os.environ.setdefault(key.strip(), value.strip())

client = ScreenerClient(
    username=os.environ["SCREENER_USERNAME"],
    password=os.environ["SCREENER_PASSWORD"],
)

# %%
client.full_text_search('ramesh damani')
# Out:
#                                         Company     Symbol  \
# 0                          V I P Industries Ltd     VIPIND
# 4   Housing & Urban Development Corporation Ltd      HUDCO
# 5     Garden Reach Shipbuilders & Engineers Ltd       GRSE
# 7                                      MSTC Ltd    MSTCLTD
# 11                  Jana Small Finance Bank Ltd       JSFB
# 12                Aditya Birla Sun Life AMC Ltd    ABSLAMC
# 13                        Avenue Supermarts Ltd      DMART
# 14                                   Aptech Ltd    APTECHT
# 18              Spandana Sphoorty Financial Ltd   SPANDANA
# 20          Hindustan Petroleum Corporation Ltd  HINDPETRO
# 24                  Quick Heal Technologies Ltd  QUICKHEAL
#
#                                                   URL
# 0   https://www.screener.in/company/VIPIND/consoli...
# 4   https://www.screener.in/company/HUDCO/consolid...
# 5               https://www.screener.in/company/GRSE/
# 7   https://www.screener.in/company/MSTCLTD/consol...
# 11              https://www.screener.in/company/JSFB/
# 12  https://www.screener.in/company/ABSLAMC/consol...
# 13  https://www.screener.in/company/DMART/consolid...
# 14  https://www.screener.in/company/APTECHT/consol...
# 18          https://www.screener.in/company/SPANDANA/
# 20  https://www.screener.in/company/HINDPETRO/cons...
# 24  https://www.screener.in/company/QUICKHEAL/cons...

# %%
mask = client.get_all_tables('reliance')

# %%
mask
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mask
#
# NameError: name 'mask' is not defined
