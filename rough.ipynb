# %%
import os
from pathlib import Path
from screener_scrapper import ScreenerClient

for line in Path(".env").read_text(encoding="utf-8").splitlines():
    line = line.strip()
    if line and not line.startswith("#") and "=" in line:
        key, value = line.split("=", 1)
        os.environ.setdefault(key.strip(), value.strip())

client = ScreenerClient(
    username=os.environ["SCREENER_USERNAME"],
    password=os.environ["SCREENER_PASSWORD"],
)

# %%
client.get_company_snapshot('reliance')
# Out:
# {'Market Cap': '₹ 17,95,296 Cr.',
#  'Current Price': '₹ 1,326',
#  'High / Low': '₹ 1,612 / 1,253',
#  'Stock P/E': '23.1',
#  'Book Value': '₹ 668',
#  'Dividend Yield': '0.45 %',
#  'ROCE': '10.3 %',
#  'ROE': '8.91 %',
#  'Face Value': '₹ 10.0',
#  'Sales\xa0+': '1055780',
#  'Expenses\xa0+': '876715',
#  'Operating Profit': '179065',
#  'OPM %': '17%',
#  'Other Income\xa0+': '28846',
#  'Interest': '27061',
#  'Depreciation': '57688',
#  'Profit before tax': '123162',
#  'Tax %': '22%',
#  'Net Profit\xa0+': '95754',
#  'EPS in Rs': '59.69',
#  'Dividend Payout %': '2%',
#  '10 Years:': '9%',
#  '5 Years:': '9%',
#  '3 Years:': '9%',
#  'TTM:': '14%',
#  '1 Year:': '-10%',
#  'Last Year:': '9%',
#  'Equity Capital': 13532,
#  'Reserves': 890498,
#  'Borrowings\xa0+': 402962,
#  'Other Liabilities\xa0+': 870554,
#  'Total Liabilities': 2177546,
#  'Fixed Assets\xa0+': 1124795,
#  'CWIP': 237686,
#  'Investments': 248332,
#  'Other Assets\xa0+': 566733,
#  'Total Assets': 2177546,
#  'Cash from Operating Activity\xa0+': '192113',
#  'Cash from Investing Activity\xa0+': '-101089',
#  'Cash from Financing Activity\xa0+': '-51549',
#  'Net Cash Flow': '39475',
#  'Free Cash Flow': '70023',
#  'CFO/OP': '113%',
#  'Debtor Days': '20',
#  'Inventory Days': '88',
#  'Days Payable': '84',
#  'Cash Conversion Cycle': '25',
#  'Working Capital Days': '-66',
#  'ROCE %': '10%',
#  'Reliance Retail - Store Count Number': 'x,xxx  x,xxx  x,xxx  x,xxx  x,xxx  x,xxx  xx,xxx  xx,xxx  xx,xxx  xx,xxx  xx,xxx  xx,xxx  xx.xx  xx.xx  xx.xx  xx.xx  xx.xx  xx.xx  xx.xx  xx.xx  xx.xx  xx.xx  xx.xx  xxx.xx  xxx.xx  xxx.xx  xxx.xx  xxx.xx  xxx.xx  xxx.xx  xxx.xx  xx.xx  xx.xx  xx.xx  xx.xx  xx.xx  xx.xx  xx.xx  xx.xx  xxx.xx  xxx.xx  xxx.xx  xxx.xx  xxx.xx  xxx.xx  xx.xx  xx.xx  xx.xx  xx.xx  xx  Unlock insights  Free users can unlock up to 5 insights tables per month.  Unlock',
#  'x,xxx': 'xx,xxx',
#  'xx.xx': 'xx.xx',
#  'Promoters\xa0+': '50.00%',
#  'FIIs\xa0+': '18.67%',
#  'DIIs\xa0+': '20.46%',
#  'Government\xa0+': '0.17%',
#  'Public\xa0+': '10.70%',
#  'No. of Shareholders': '4421289'}

# %%
mask = client.get_all_tables('reliance')

# %%
mask[12]
# Out:
#             Unnamed: 0 Mar 2017 Mar 2018 Mar 2019 Mar 2020 Mar 2021 Mar 2022  \
# 0          Promoters +   46.32%   47.45%   47.27%   50.07%   50.58%   50.66%
# 1               FIIs +   22.58%   24.46%   24.39%   24.08%   25.66%   24.23%
# 2               DIIs +   11.85%   11.23%   11.86%   13.78%   12.62%   14.23%
# 3         Government +    0.14%    0.15%    0.18%    0.20%    0.20%    0.17%
# 4             Public +   19.12%   16.72%   16.29%   11.87%   10.94%   10.71%
# 5  No. of Shareholders  2501302  2266000  2211231  2632168  3031272  3327847
#
#   Mar 2023 Mar 2024 Mar 2025 Mar 2026
# 0   50.41%   50.31%   50.10%   50.00%
# 1   22.49%   22.06%   19.07%   18.67%
# 2   16.06%   16.98%   19.36%   20.46%
# 3    0.16%    0.19%    0.17%    0.17%
# 4   10.89%   10.46%   11.29%   10.70%
# 5  3639396  3463276  4765728  4421289
